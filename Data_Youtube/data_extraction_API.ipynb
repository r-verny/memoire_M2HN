# %% [markdown]
# On installe au préalable *google-api-python-client* pour récupérer des données depuis l'API Youtube

# %%
from googleapiclient.discovery import build

api_key ="AIzaSyD8KRE7qSVM-ppbcYgM4eRfCCwC1-PMp9o"
video_id= "APXatt1iX1w"

# %%
resource = build('youtube', 'v3', developerKey=api_key)

# %%
request = resource.commentThreads().list(
                            part=["snippet", "replies"],
                            videoId=video_id,
                            maxResults= 100,
                            order="relevance")

# %%
response =request.execute()

# %%
items = response["items"]

# %%
items
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'JvRAhTDsamzm0m90IIesQx9wyUk',
#   'id': 'UgycqLDHW6boQvao0n54AaABAg',
#   'snippet': {'videoId': 'JW8WWW3rBtE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '-JBkUtPG1gI-xefKsvDLIY6SnKI',
#     'id': 'UgycqLDHW6boQvao0n54AaABAg',
#     'snippet': {'videoId': 'JW8WWW3rBtE',
#      'textDisplay': 'Deus vult 🏅🇨🇵<br>Force a toi ,tu en auras bien besoin. Fière d&#39;être français et de l&#39;histoire de mon pays',
#      'textOriginal': "Deus vult 🏅🇨🇵\nForce a toi ,tu en auras bien besoin. Fière d'être français et de l'histoire de mon pays",
#      'authorDisplayName': 'Geralt deriv',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTcg6lpzZTeeDF8NxI0-Hc0tTj1cpu3AaAmHUCAAA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCuHffjyRz8ifqOgIzKs_dOA',
#      'authorChannelId': {'value': 'UCuHffjyRz8ifqOgIzKs_dOA'},
#      'canRate': True,
#      'viewerRating': 'none',
# ...

# %%
print("------------------------------------------------------------------------------------------------------")
for item in items:
    item_info = item["snippet"]
    
    #the top level comment can have sub reply comments
    topLevelComment = item_info["topLevelComment"]
    comment_info = topLevelComment["snippet"]
    
    print("Comment Text:" ,comment_info["textDisplay"])
    print("================================\n")
# Out:
# ------------------------------------------------------------------------------------------------------
# Comment Text: Pourquoi mettre des titres de vidéos en anglais ? alors que les anglos ont eu sacro-sainte horreur des Français et des francophones plus généralement.  S&#39;émanciper c&#39;est aussi construire un monde en dehors du système anglo-saxon.
# ...
#
# Comment Text: Jeanne d&#39;Arc était très catholique, elle dirigeait des gens très catholiques. Sans cela, qu&#39;est-ce qui réunirait les gens sous une nouvelle « Jeanne d&#39;Arc » ?
# ...
#
# ...

# %% [markdown]
# On va maintenant extraire les données de 10 vidéos sur les chaînes TE et Valek

# %%
from googleapiclient.discovery import build

api_key ="AIzaSyD8KRE7qSVM-ppbcYgM4eRfCCwC1-PMp9o"
video_id_TE= ["JW8WWW3rBtE",
              "APXatt1iX1w", 
              "osP7cR8wARw", 
              "7fJJlaJIfQU", 
              "K_84dGbp-Y8", 
              "cSuSAfVw96Y", 
              "5oIqE0mNwNY", 
              "hXOUabGChPU", 
              "sUE6wSLgY-I", 
              "YrOfoccF7vA"]
video_id_VA= ["Z18kxQXRLeU", 
              "1nKyAs7bifE", 
              "GS1Td9oS1A8", 
              "CurKWUXJI7Q", 
              "6DS4UxjvS7E", 
              "n1cUWxKKdYc", 
              "irU-w7ivnpg", 
              "eIgzkFU9mQk", 
              "XAESrfgBiXs", 
              "pGZSE_RMJbc"]

# %%
resource = build('youtube', 'v3', developerKey=api_key)

# %%
comms_TE = []

for video_id in video_id_TE:
    request = resource.commentThreads().list(
                            part=["snippet", "replies"],
                            videoId=video_id,
                            maxResults= 100,
                            order="relevance")
    response =request.execute()
    items = response["items"]
    for item in items:
        item_info = item["snippet"]
        topLevelComment = item_info["topLevelComment"]
        comment_info = topLevelComment["snippet"]
        comms_TE.append(comment_info["textDisplay"])
        
        if "replies" in item:
            item_infos = item["replies"]
            for comment in item_infos["comments"]:
                comms_TE.append(comment["snippet"]["textDisplay"])

# %%
len(comms_TE)
# Out:
# 1848

# %%
comms_VA = []

for video_id in video_id_VA:
    request = resource.commentThreads().list(
                            part=["snippet", "replies"],
                            videoId=video_id,
                            maxResults= 100,
                            order="relevance")
    response =request.execute()
    items = response["items"]
    for item in items:
        item_info = item["snippet"]
        topLevelComment = item_info["topLevelComment"]
        comment_info = topLevelComment["snippet"]
        comms_VA.append(comment_info["textDisplay"])
        
        if "replies" in item:
            item_infos = item["replies"]
            for comment in item_infos["comments"]:
                comms_VA.append(comment["snippet"]["textDisplay"])

# %%
len(comms_VA)
# Out:
# 1975

# %%
comms_TE_txt = open ("comms_TE.txt","w", encoding="utf-8")
for element in comms_TE:
    comms_TE_txt.write(element + "\n")
comms_TE_txt.close()

# %%
comms_VA_txt = open ("comms_VA.txt","w", encoding="utf-8")
for element in comms_VA:
    comms_VA_txt.write(element + "\n")
comms_VA_txt.close()
